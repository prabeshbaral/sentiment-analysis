# %%
import pandas as pd
import numpy as np

# %%
#reading the dataset
trainin_df=pd.read_csv('datasets/twitter_training.csv')
testing_df=pd.read_csv('datasets/twitter_validation.csv')

# %%
trainin_df.sample(5)
# Out:
#        2401  Borderlands    Positive  \
# 14269  2846        Dota2    Negative
# 1530   2668  Borderlands    Negative
# 72854  8880       Nvidia    Negative
# 24180  4545       Google  Irrelevant
# 22074  4178        CS-GO  Irrelevant
#
#       im getting on borderlands and i will murder you all ,
# 14269  why is huskar a hero in dota 2 and why cant i ...
# 1530   Ok, so for every major advance I see in Border...
# 72854  Don't get mad Nvidia can release a card or the...
# 24180  Someone saw me rt this and was like you rt tha...
# 22074                           Her also dogshit at csgo
